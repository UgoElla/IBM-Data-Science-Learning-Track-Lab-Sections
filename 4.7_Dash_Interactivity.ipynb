# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/labs/Module%204/logo.png" width="300" alt="cognitiveclass.ai logo" />
# </center>

# %% [markdown]
# # Objectives
#
# In this lab, you will work on Dash Callbacks.
#
# ## Dataset Used
#
# [Airline Reporting Carrier On-Time Performance](https://developer.ibm.com/exchanges/data/all/airline/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01) dataset from [Data Asset eXchange](https://developer.ibm.com/exchanges/data/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01)
#
# ## Lab Question
#
# Extract average monthly arrival delay time and see how it changes over the year.
#
# ## Dash Application Creation
#
# ### Todo for the lab question
#
# 1.  Import required libraries, read the airline data, and create an application layout
# 2.  Add title to the dashboard using HTML H1 component
# 3.  Add a HTML division and core text input component inside the division. Provide an input component id and a default value to the component.
# 4.  Add a HTML dividion and core graph component. Provide a graph component id.
# 5.  Add callback decorator and provide input and output parameters.
# 6.  Define callback function, perform computation to extract required information, create the graph, and update the layout.
# 7.  Run the app
#
# ## Hints
#
# General examples can be found [here](https://dash.plotly.com/layout?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01).
#
# *   For step 1 (only review), this is very specific to running app from Jupyerlab.
#
#     *   For Jupyterlab,we will be using `jupyter-dash` library. Adding `from jupyter_dash import JupyterDash` import statement.
#     *   Instead of creating dash application using `app = dash.Dash()`, we will be using `app = JupyterDash(__name__)`.
#     *   Use pandas to read the airline data.
# *   For step 2,
#
#     *   [Plotly H1 HTML Component](https://dash.plotly.com/dash-html-components/h1?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01)
#
#     *   Title as `Airline Performance Dashboard`
#
#     *   Use `style` parameter and make the title center aligned, with color code `#503D36`, and font-size as 40. Check `More about HTML` section [here](https://dash.plotly.com/layout?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01).
# *   For step 3,
#
#     *   Add [dcc input](https://dash.plotly.com/dash-core-components/input?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01) component and provide id as `input-year`. Use `style` parameter and assign height of the inout box to be `50px` and font-size to be `35`.
#
#     *   HTML [Div](https://dash.plotly.com/dash-html-components/div?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01) component and provide id as `line-plot`. Use `style` parameter and assign font-size as `40`.
# *   For step 4,
#
#     *   Core [graph](https://dash.plotly.com/dash-core-components/graph?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01) component and assign id as `line-plot`.
# *   For 5 and 6,
#
#     *   Basic [callback](https://dash.plotly.com/basic-callbacks?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01)

# %% [markdown]
# ## App Skeleton
#
# ```python
#
# import dash
# ....
# ....
# from jupyter_dash import JupyterDash
#
#
# app = JupyterDash(__name__)
# JupyterDash.infer_jupyter_proxy_config()
#
#
# app.layout = html.Div(children=[html.H1(.......),
#                                 html.Div(['Input:', dcc.Input(id='..', value='..', type='..', style={})], style={}),
#                                 html.Br(),
#                                 html.Br(),
#                                 html.Div(dcc.Graph(id='..')),
#                                ])
#
# if __name__ == '__main__':
#     app.run_server(mode="inline", host="localhost")
#
# ```

# %%
# !pip install dash
# !pip install dash==1.19.0
# !pip install jupyter_dash
# !pip install --upgrade plotly
# Out:
# Requirement already satisfied: dash in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (1.19.0)
# Requirement already satisfied: Flask>=1.0.4 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from dash) (2.0.1)
# Requirement already satisfied: flask-compress in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from dash) (0.0.0)
# Requirement already satisfied: dash-html-components==1.1.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from dash) (1.1.2)
# Requirement already satisfied: dash-renderer==1.9.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from dash) (1.9.0)
# Requirement already satisfied: plotly in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from dash) (5.1.0)
# Requirement already satisfied: dash-core-components==1.15.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from dash) (1.15.0)
# Requirement already satisfied: dash-table==4.11.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from dash) (4.11.2)
# Requirement already satisfied: future in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from dash) (0.18.2)
# Requirement already satisfied: Jinja2>=3.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from Flask>=1.0.4->dash) (3.0.1)
# Requirement already satisfied: Werkzeug>=2.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: itsdangerous>=2.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: click>=7.1.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from Flask>=1.0.4->dash) (8.0.1)
# Requirement already satisfied: brotli in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from flask-compress->dash) (1.0.9)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from plotly->dash) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from plotly->dash) (8.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from Werkzeug>=2.0->Flask>=1.0.4->dash) (0.8)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from click>=7.1.2->Flask>=1.0.4->dash) (4.6.1)
# Requirement already satisfied: zipp>=0.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->click>=7.1.2->Flask>=1.0.4->dash) (3.5.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->click>=7.1.2->Flask>=1.0.4->dash) (3.10.0.0)
# Requirement already satisfied: dash==1.19.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (1.19.0)
# Requirement already satisfied: Flask>=1.0.4 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from dash==1.19.0) (2.0.1)
# Requirement already satisfied: flask-compress in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from dash==1.19.0) (0.0.0)
# Requirement already satisfied: dash-html-components==1.1.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from dash==1.19.0) (1.1.2)
# Requirement already satisfied: dash-renderer==1.9.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from dash==1.19.0) (1.9.0)
# Requirement already satisfied: plotly in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from dash==1.19.0) (5.1.0)
# Requirement already satisfied: dash-core-components==1.15.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from dash==1.19.0) (1.15.0)
# Requirement already satisfied: dash-table==4.11.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from dash==1.19.0) (4.11.2)
# Requirement already satisfied: future in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from dash==1.19.0) (0.18.2)
# Requirement already satisfied: Jinja2>=3.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from Flask>=1.0.4->dash==1.19.0) (3.0.1)
# Requirement already satisfied: Werkzeug>=2.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from Flask>=1.0.4->dash==1.19.0) (2.0.1)
# Requirement already satisfied: itsdangerous>=2.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from Flask>=1.0.4->dash==1.19.0) (2.0.1)
# Requirement already satisfied: click>=7.1.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from Flask>=1.0.4->dash==1.19.0) (8.0.1)
# Requirement already satisfied: brotli in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from flask-compress->dash==1.19.0) (1.0.9)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from plotly->dash==1.19.0) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from plotly->dash==1.19.0) (8.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash==1.19.0) (2.0.1)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from Werkzeug>=2.0->Flask>=1.0.4->dash==1.19.0) (0.8)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from click>=7.1.2->Flask>=1.0.4->dash==1.19.0) (4.6.1)
# Requirement already satisfied: zipp>=0.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->click>=7.1.2->Flask>=1.0.4->dash==1.19.0) (3.5.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->click>=7.1.2->Flask>=1.0.4->dash==1.19.0) (3.10.0.0)
# Requirement already satisfied: jupyter_dash in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.4.0)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jupyter_dash) (2.25.1)
# Requirement already satisfied: ipython in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jupyter_dash) (7.16.1)
# Requirement already satisfied: ansi2html in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jupyter_dash) (0.0.0)
# Requirement already satisfied: retrying in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jupyter_dash) (1.3.3)
# Requirement already satisfied: ipykernel in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jupyter_dash) (5.5.5)
# Requirement already satisfied: flask in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jupyter_dash) (2.0.1)
# Requirement already satisfied: dash in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->jupyter_dash) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->jupyter_dash) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->jupyter_dash) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->jupyter_dash) (4.0.0)
# Requirement already satisfied: decorator in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ipython->jupyter_dash) (4.4.2)
# Requirement already satisfied: backcall in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ipython->jupyter_dash) (3.0.19)
# Requirement already satisfied: pygments in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ipython->jupyter_dash) (2.9.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ipython->jupyter_dash) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ipython->jupyter_dash) (4.3.3)
# Requirement already satisfied: jedi>=0.10 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ipython->jupyter_dash) (0.17.2)
# Requirement already satisfied: pickleshare in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ipython->jupyter_dash) (49.6.0.post20210108)
# Requirement already satisfied: six>=1.7.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from retrying->jupyter_dash) (1.15.0)
# Requirement already satisfied: tornado>=4.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: jupyter-client in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ipykernel->jupyter_dash) (6.1.12)
# Requirement already satisfied: Jinja2>=3.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from flask->jupyter_dash) (3.0.1)
# Requirement already satisfied: Werkzeug>=2.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: itsdangerous>=2.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: click>=7.1.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from flask->jupyter_dash) (8.0.1)
# Requirement already satisfied: flask-compress in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from dash->jupyter_dash) (0.0.0)
# Requirement already satisfied: dash-html-components==1.1.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: dash-renderer==1.9.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: plotly in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from dash->jupyter_dash) (5.1.0)
# Requirement already satisfied: dash-core-components==1.15.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: dash-table==4.11.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: future in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from dash->jupyter_dash) (0.18.2)
# Requirement already satisfied: wcwidth in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython->jupyter_dash) (0.7.0)
# Requirement already satisfied: ipython-genutils in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from traitlets>=4.2->ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jedi>=0.10->ipython->jupyter_dash) (0.7.1)
# Requirement already satisfied: pyzmq>=13 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jupyter-client->ipykernel->jupyter_dash) (22.1.0)
# Requirement already satisfied: python-dateutil>=2.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jupyter-client->ipykernel->jupyter_dash) (2.8.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jupyter-client->ipykernel->jupyter_dash) (4.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from Jinja2>=3.0->flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from Werkzeug>=2.0->flask->jupyter_dash) (0.8)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from click>=7.1.2->flask->jupyter_dash) (4.6.1)
# Requirement already satisfied: brotli in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from flask-compress->dash->jupyter_dash) (1.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from plotly->dash->jupyter_dash) (8.0.1)
# Requirement already satisfied: zipp>=0.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->click>=7.1.2->flask->jupyter_dash) (3.5.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->click>=7.1.2->flask->jupyter_dash) (3.10.0.0)
# Requirement already up-to-date: plotly in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (5.1.0)
# Requirement already satisfied, skipping upgrade: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from plotly) (1.15.0)
# Requirement already satisfied, skipping upgrade: tenacity>=6.2.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from plotly) (8.0.1)

# %%
# Import required libraries
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash
import plotly.graph_objects as go

# %%
JupyterDash.infer_jupyter_proxy_config()

# %%
 # needs to be run again in a separate cell due to a jupyterdash bug
JupyterDash.infer_jupyter_proxy_config()

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- The answer is below:
#
# # Create a dash application
# app = JupyterDash(__name__)
#
# # Read the airline data into pandas dataframe
# airline_data =  pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/airline_data.csv',
#                             encoding = "ISO-8859-1",
#                             dtype={'Div1Airport': str, 'Div1TailNum': str,
#                                    'Div2Airport': str, 'Div2TailNum': str})
#
# # TODO
# # Get the layout of the application and adjust it.
# # Create an outer division using html.Div and add title to the dashboard using html.H1 component
# # Add a html.Div and core input text component
# # Finally, add graph component.
# app.layout = html.Div(children=[ html.H1('Airline Performance Dashboard',
#                                 style={'textAlign': 'center', 'color': '#503D36',
#                                 'font-size': 40}),
#                                 html.Div(["Input Year: ", dcc.Input(id='input-year', value='2010',
#                                 type='number', style={'height':'50px', 'font-size': 35}),],
#                                 style={'font-size': 40}),
#                                 html.Br(),
#                                 html.Br(),
#                                 html.Div(dcc.Graph(id='line-plot')),
#                                 ])
#
# # add callback decorator
# @app.callback( Output(component_id='line-plot', component_property='figure'),
#                Input(component_id='input-year', component_property='value'))
#
# # Add computation to callback function and return graph
# def get_graph(entered_year):
#     # Select 2019 data
#     df =  airline_data[airline_data['Year']==int(entered_year)]
#
#     # Group the data by Month and compute average over arrival delay time.
#     line_data = df.groupby('Month')['ArrDelay'].mean().reset_index()
#
#     fig = go.Figure(data=go.Scatter(x=line_data['Month'], y=line_data['ArrDelay'], mode='lines', marker=dict(color='green')))
#     fig.update_layout(title='Month vs Average Flight Delay Time', xaxis_title='Month', yaxis_title='ArrDelay')
#     return fig
#
# # Run the app
# if __name__ == '__main__':
#     app.run_server(mode="inline", host="localhost")
#
# -->

# %%
# Solution below
# Create a dash application
app = JupyterDash(__name__) # if not using JupyterDash this would be: app = dash.Dash(__name__)

# Read the airline data into pandas dataframe
airline_data =  pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/airline_data.csv', 
                            encoding = "ISO-8859-1",
                            dtype={'Div1Airport': str, 'Div1TailNum': str, 
                                   'Div2Airport': str, 'Div2TailNum': str})

# Get the layout of the application and adjust it.
# Create an outer division using html.Div and add title to the dashboard using html.H1 component
# Add a html.Div and core input text component
# Finally, add graph component.
app.layout = html.Div(children=[ html.H1('Airline Performance Dashboard', 
                                style={'textAlign': 'center', 'color': '#503D36',
                                'font-size': 40}),
                                html.Div(["Input Year: ", dcc.Input(id='input-year', value='2010', 
                                type='number', style={'height':'50px', 'font-size': 35}),], 
                                style={'font-size': 40}),
                                html.Br(),
                                html.Br(),
                                html.Div(dcc.Graph(id='line-plot')),
                                ])

# add callback decorator
@app.callback( Output(component_id='line-plot', component_property='figure'),
               Input(component_id='input-year', component_property='value'))

# Add computation to callback function and return graph
def get_graph(entered_year):
    # Select 2019 data
    df =  airline_data[airline_data['Year']==int(entered_year)]

    # Group the data by Month and compute average over arrival delay time.
    line_data = df.groupby('Month')['ArrDelay'].mean().reset_index()

    fig = go.Figure(data=go.Scatter(x=line_data['Month'], y=line_data['ArrDelay'], mode='lines', marker=dict(color='green')))
    fig.update_layout(title='Month vs Average Flight Delay Time', xaxis_title='Month', yaxis_title='ArrDelay')
    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(mode='inline', host='localhost')
#     app.run_server()
#     if that does not work some other ways would be
#     app.run_server(mode="inline", host="127.0.0.1", port=8050)
#     app.run_server(mode='jupyterlab')
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://localhost:8050/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Jupyter Dash readme https://www.npmjs.com/package/jupyterlab-dash mentions some possible solutions:
# Make sure JupyterLab version 2.0 or above
# This extension is included with the Python package,
# but in order to activate it JupyterLab must be rebuilt.
# JupyterLab should automatically produce a popup dialog 
# asking for permission to rebuild,but the rebuild can 
# also be performed manually from the command line using:
# !jupyter lab build
# To check that the extension is installed properly, call:
# !jupyter labextension list
# Out:
# Traceback (most recent call last):
#   File "/home/jupyterlab/conda/envs/python/bin/jupyter", line 11, in <module>
#     sys.exit(main())
#   File "/home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/jupyter_core/command.py", line 285, in main
#     command = _jupyter_abspath(subcommand)
#   File "/home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/jupyter_core/command.py", line 125, in _jupyter_abspath
#     'Jupyter command `{}` not found.'.format(jupyter_subcommand)
# Exception: Jupyter command `jupyter-lab` not found.

# %% [markdown]
# ## Summary
#
# Congratulations for completing your dash interactivity lab.
#
# In this lab, you have learnt how to make dash HTML and core components interact with each other for creating dashboard.

# %% [markdown]
# ## Author
#
# [Saishruthi Swaminathan](https://www.linkedin.com/in/saishruthi-swaminathan/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01)

# %% [markdown]
# ## Changelog
#
# | Date       | Version | Changed by | Change Description                   |
# | ---------- | ------- | ---------- | ------------------------------------ |
# | 12-18-2020 | 1.0     | Nayef      | Added dataset link and upload to Git |

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
